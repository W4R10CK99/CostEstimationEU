# %%
# !pip install ctgan
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 50.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade ctgan scikit-learn threadpoolctl --user
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 39.1 MB/s eta 0:00:00
# ...

# %%
from ctgan import CTGAN
from ctgan import load_demo

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/yearRecord.csv')

# %%
print(df.dtypes)
# Out:
# AssetTypeID                 int64
# AssetType                  object
# YearsAfterInstallation    float64
# WorkDescription            object
# Spend_ExGST               float64
# dtype: object

# %%
newDf[['AssetID','Years','Cost']] = df.loc[:,['AssetTypeID','YearsAfterInstallation','Spend_ExGST']]

# %%
newDf = newDf.loc[ : ,['AssetID','Years','Cost']]

# %%
newDf.head()
# Out:
#    AssetID  Years  Cost
# 0       89   25.0   0.0
# 1       10    4.0   0.0
# 2       10    4.0   0.0
# 3       89   20.0   0.0
# 4       89   19.0   0.0

# %%
newDf = newDf[newDf['Cost']>0]

# %%
newDf.value_counts()
# Out:
# AssetID  Years  Cost
# 251      13.0   1046.57    27
#                 4651.19    27
#                 1688.67    27
#                 1399.45    27
#                 1219.75    27
#                            ..
# 51       10.0   7670.00     1
#                 3687.89     1
#                 3489.00     1
#                 1389.00     1
# 442      31.0   1732.28     1
# Length: 5092, dtype: int64

# %%
newDf
# Out:
#        AssetID  Years     Cost
# 6           91   19.0   280.00
# 7           91   19.0   280.00
# 8           91   12.0   280.00
# 9           91   19.0   280.00
# 10          15   22.0   940.75
# ...        ...    ...      ...
# 10826      238   12.0   352.60
# 10827      238   12.0   131.50
# 10828      238   13.0  1837.92
# 10829      238   12.0   120.67
# 10830      238   12.0   131.50
#
# [6394 rows x 3 columns]

# %%
#reset index
newDf.reset_index(drop=True, inplace=True)
newDf
# Out:
#       AssetID  Years     Cost
# 0          91   19.0   280.00
# 1          91   19.0   280.00
# 2          91   12.0   280.00
# 3          91   19.0   280.00
# 4          15   22.0   940.75
# ...       ...    ...      ...
# 6389      238   12.0   352.60
# 6390      238   12.0   131.50
# 6391      238   13.0  1837.92
# 6392      238   12.0   120.67
# 6393      238   12.0   131.50
#
# [6394 rows x 3 columns]

# %%
discrete_columns=[
    'AssetID',
    'Years',
]

# %%
pip install tqdm

# %%
ctgan = CTGAN(epochs=10)

# %%
from tqdm import tqdm

# %%
for epoch in tqdm(range(1, 11), desc="Training CTGAN", unit="epoch"):
    ctgan.fit(newDf, discrete_columns)
# Out:
# Training CTGAN: 100%|██████████| 10/10 [03:38<00:00, 21.89s/epoch]

# %%
synthetic_data = ctgan.sample(300000)
synthetic_data.head()
# Out:
#    AssetID  Years         Cost
# 0       15   11.0   147.356888
# 1      208    0.0   784.677819
# 2      208   26.0   260.820536
# 3      123   14.0   802.381345
# 4      367   16.0  1006.527620

# %%
synthetic_data.to_csv('synthetic_300k.csv', index=False)

# %%
# prompt: can we generate the synthetic dataset, that is based on train_data

ctgan5 = CTGAN(epochs=10)
discrete_columns=[
    'AssetTypeID',
    'YearsAfterInstallation',
]
for epoch in tqdm(range(1, 11), desc="Training CTGAN", unit="epoch"):
    ctgan5.fit(train_data, discrete_columns)
synthetic_data5 = ctgan5.sample(1000)
synthetic_data5
