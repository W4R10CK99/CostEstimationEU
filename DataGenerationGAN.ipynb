# %%
pip install ctgan
# Out:
# ...
#      ---------------------------------------- 76.2/76.2 kB 4.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 198.5/198.5 MB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ctgan import CTGAN
from ctgan import load_demo

# %%
real_data = load_demo()

# %%
real_data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

# %%
ctgan = CTGAN(epochs=10)
ctgan.fit(real_data,discrete_columns)

# %%
synthetic_data = ctgan.sample(1000)
synthetic_data.head()
# Out:
#    age      workclass  fnlwgt   education  education-num       marital-status  \
# 0   37        Private  141125     Masters              9        Never-married
# 1   14        Private   26786   Assoc-voc             12        Never-married
# 2   55   Never-worked  115394         9th             11   Married-civ-spouse
# 3   31        Private  207641   Bachelors             14             Divorced
# 4   44        Private  166684     HS-grad             12   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Craft-repair         Husband   White     Male           101
# 1      Prof-specialty         Husband   White     Male          -146
# 2       Other-service         Husband   White     Male            18
# 3               Sales         Husband   White     Male            69
# 4   Machine-op-inspct   Not-in-family   White   Female          -113
#
#    capital-loss  hours-per-week  native-country  income
# ...

# %%
real_data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
import pandas as pd

# %%
real_df = pd.read_csv('Dataset/yearRecord.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26276\2003911534.py in <module>
#       1 real_df = pd.read_csv('Dataset/yearRecord.csv')
# ----> 2 read_df
#
# NameError: name 'read_df' is not defined

# %%
real_df
# Out:
#        AssetTypeID                  AssetType  YearsAfterInstallation  \
# 0               89        DUCTED SPLIT SYSTEM                    25.0
# 1               10          AIR FAN - EXHAUST                     4.0
# 2               10          AIR FAN - EXHAUST                     4.0
# 3               89        DUCTED SPLIT SYSTEM                    20.0
# 4               89        DUCTED SPLIT SYSTEM                    19.0
# ...            ...                        ...                     ...
# 10826          238  VARIABLE AIR VOLUME UNITS                    12.0
# 10827          238  VARIABLE AIR VOLUME UNITS                    12.0
# 10828          238  VARIABLE AIR VOLUME UNITS                    13.0
# 10829          238  VARIABLE AIR VOLUME UNITS                    12.0
# 10830          238  VARIABLE AIR VOLUME UNITS                    12.0
#
#                       WorkDescription  Spend_ExGST
# 0       Ex Taste of Korea AC reactive         0.00
# ...

# %%
print(real_df.dtypes)
# Out:
# AssetTypeID                 int64
# AssetType                  object
# YearsAfterInstallation    float64
# WorkDescription            object
# Spend_ExGST               float64
# dtype: object

# %%
df['YearsAfterInstallation'].fillna(1, inplace=True)
df['YearsAfterInstallation'] = df['YearsAfterInstallation'].astype(int)

# %%
df['AssetType'] = df['AssetType'].astype(str)
df['WorkDescription'] = df['WorkDescription'].astype(str)

# %%
# Display updated data types
print("\nUpdated Data Types:")
print(df.dtypes)
# Out:
# Updated Data Types:
# AssetTypeID                 int64
# AssetType                  object
# YearsAfterInstallation      int32
# WorkDescription            object
# Spend_ExGST               float64
# dtype: object

# %%
discrete_columns=[
    'AssetTypeID',
    'AssetType',
    'YearsAfterInstallation',
    'WorkDescription'
]

# %%
ctgan2 = CTGAN(epochs=10)
ctgan.fit(df,discrete_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26276\885530418.py in <module>
#       1 ctgan2 = CTGAN(epochs=10)
# ----> 2 ctgan.fit(df,discrete_columns)
#
# C:\ML\lib\site-packages\ctgan\synthesizers\base.py in wrapper(self, *args, **kwargs)
#      48     def wrapper(self, *args, **kwargs):
#      49         if self.random_states is None:
# ---> 50             return function(self, *args, **kwargs)
#      51
#      52         else:
#
# C:\ML\lib\site-packages\ctgan\synthesizers\ctgan.py in fit(self, train_data, discrete_columns, epochs)
#     391                     optimizerD.zero_grad(set_to_none=False)
#     392                     pen.backward(retain_graph=True)
# --> 393                     loss_d.backward()
#     394                     optimizerD.step()
#     395
#
# ...

# %%
print(df['WorkDescription'])
# Out:
# 0         Ex Taste of Korea AC reactive
# 1        General exhaust fan isolator i
# 2        General exhaust fan isolator i
# 3           LG- Heat Pump NO# 2 Repairs
# 4        L17 Quorom Comms. Room PCB Rep
#                       ...
# 10826        BASEMENT CHEMIST WAREHOUSE
# 10827     CHEMIST WAREHOUSE INVEST WARM
# 10828    Chemist Warehouse VAV-B1-1 Con
# 10829        AHU-4B1 ISSUES 100% RETAIL
# 10830     CHEMIST WAREHOUSE INVEST WARM
# Name: WorkDescription, Length: 10831, dtype: object

# %%
print(df['WorkDescription'].nunique())
# Out:
# 7908

# %%
print(df['AssetType'].nunique())
# Out:
# 160

# %%
print(df['YearsAfterInstallation'].nunique())
# Out:
# 82

# %%
print(df['YearsAfterInstallation'].unique())
# Out:
# [  25    4   20   19   12   22    9   10   16    7   11    3   17   32
#     0   21   13   23   15   45    6   14    2   44    8    5  123  122
#    29   26   18    1   33   24   30   28   27   34   31   36   38   42
#    57   46   52   47   35   48   49   43   41   51   50   39   53   54
#    60  -96  -98   37 -113   40 -101  -97 -106 -115  -91 -108 -102 -100
#  -111   -3   -1 -121   64   65 -105 -110   -2   62   61 -118]

# %%
for column in real_data.columns:
        unique_values = real_data[column].nunique()
        print(f"Number of unique values in '{column}': {unique_values}")
# Out:
# Number of unique values in 'age': 73
# Number of unique values in 'workclass': 9
# Number of unique values in 'fnlwgt': 21648
# Number of unique values in 'education': 16
# Number of unique values in 'education-num': 16
# Number of unique values in 'marital-status': 7
# Number of unique values in 'occupation': 15
# Number of unique values in 'relationship': 6
# Number of unique values in 'race': 5
# Number of unique values in 'sex': 2
# Number of unique values in 'capital-gain': 119
# Number of unique values in 'capital-loss': 92
# Number of unique values in 'hours-per-week': 94
# Number of unique values in 'native-country': 42
# Number of unique values in 'income': 2

# %%
for column in df.columns:
        unique_values = df[column].nunique()
        print(f"Number of unique values in '{column}': {unique_values}")
# Out:
# Number of unique values in 'AssetTypeID': 160
# Number of unique values in 'AssetType': 160
# Number of unique values in 'YearsAfterInstallation': 82
# Number of unique values in 'WorkDescription': 7908
# Number of unique values in 'Spend_ExGST': 3819

# %%
count_less_than_0 = len(df[df['YearsAfterInstallation'] < 0])
count_more_than_40 = len(df[df['YearsAfterInstallation'] > 40])

# Print the results
print(f"Number of records with 'YearsAfterInstallation' less than 0: {count_less_than_0}")
print(f"Number of records with 'YearsAfterInstallation' more than 40: {count_more_than_40}")
# Out:
# Number of records with 'YearsAfterInstallation' less than 0: 38
# Number of records with 'YearsAfterInstallation' more than 40: 183

# %%
filtered_df = df[(df['YearsAfterInstallation'] >= 0) & (df['YearsAfterInstallation'] <= 40)]

# %%
print(filtered_df['YearsAfterInstallation'].nunique())
# Out:
# 41
